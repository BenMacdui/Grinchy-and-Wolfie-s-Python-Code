# %% [markdown]
# <a href="https://colab.research.google.com/github/BenMacdui/Grinchy-and-Wolfie-s-Python-Code/blob/main/Adventure_game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from random import randint 
import random
import time
from IPython.display import clear_output



print("""Two lovely ladies skipped along a field of flowers when they suddenly
saw the mean pirate at the horizon with his pet wolf. 

The ladies didn't know what the pirate was up to but he looked mean. 
There is a cave on their right side which looked dark and a spider is dangling from it's entrance. 
On the left the is a house with a welcoming face in the window, watching them.
What should the ladies do? Face the mean pirate, run to the caves or the house? """)

choice =""
while choice != 'l' and choice != 'r':
    choice = input('do they go left to the house or righ? Enter l or r: ')
print()
print()
if choice == 'l':
    print("""the lovely ladies go to the house with the friendly face. But the woman in the house
          doesn't want to open the door as she fears that the two lovely ladies are really two evil 
          witches out to get her. So she poses a puzzle for them to solve as she knows witches don't like solving
          puzzles. 
    
          She says: The evil witches only speak German so you need to tell me the
          English word of a random chosen word, only then can I be sure that you are not some witches who come to get me.
          But if you don't know the translation of the word you will be turned to stone
    """)
    German_word_list = ['Milch', 'Eier', 'Schule', 'heute']
    word = random.choice(German_word_list)
    print(word)
    print()
    answer = input("what is the english translation? ")
    print()
    print()
    if word == 'Milch' and answer == 'milk':
        print()
        print('That is the right answer. You can come in. The two lovely ladies lived happily ever after')
    elif word == 'Eier' and answer == 'eggs':
        print('That is the right answer. You can come in. The two lovely ladies lived happily ever after')
    elif word == 'Schule' and answer == 'school':
        print('That is the right answer. You can come in. The two lovely ladies lived happily ever after')
    elif word == 'heute' and answer == 'today':
        print('That is the right answer. You can come in. The two lovely ladies lived happily ever after')
    else:
        print('Wrong answer: You die')
        

        
elif choice == 'r':
    print("""The two lovely ladies run to the cave where the spider danlged from the entrance and the inside 
    very, very dark and scary. But the two lovely ladies had no choice, as the pirate was approaching 
    really fast. 
    
    The spider looked scary too. It had nine eyes and huge fangs. I looked them with her nine eyes and said:
    So you came here to hide?
    
    The two lovely laddies noddedd their head, as they were too scared to say something.
    
    The spider starred at them and for a moment the two lovely ladies thought the spider would jump 
    and bit them but the spider said. You come to the right place. Inside there is a lovely fire and
    some food that will keep you cosy and warm and you no go hungry while you hide. 
    
    But, added the spider, inside lives a friendly ogre who loves nothing more than playing Rock, Sissors and 
    Paper. He likes to play but if you loose 3 times he will eat you but if you win 3 times or if it is a draw
    he will let you stay as long as you like and no-one will find you.
    
    Faced with either confronting the mean pirate and his pet wolf or the ogre and a nice fire and a warm meal
    the lovely ladies walked into the dark cave, but as soon as they entered the spider closed a door behind 
    them and a fire began to roar and a scorpion carried snacks and placed them on a table in front of them.
    
    Not far from the table sat a big green ugly ogre who smiled and said: Welcome to my home. Eat and drink and
    when you done we play a game of Rock, Sissors and Paper: Best out of 3.
    
    The two lovely ladies nodded and began to eat when they finished the ogre said: Let's play""")
    print()
    print()

# create a list of play options
    t = ['rock', 'sissors', 'paper']

#assign the ogre random play



# We set our counters to zero and then add into them to keep
# a tally on the score
    ogrecount = c = 0
    playercount = p = 0
    tie = 0


# set run to true so that it runs while true, till interrupted with q

    run = 3
# the main loop: this will run till the user inputs q (for quit)
    while run > 0:
        ogre = t[randint(0,2)]
        run -= 1
    
#after the beginning of the main loop (here a while loop),
# we clear all output from before. It makes for a nicer screen


# turn all input into lower case alphabet with .lower() function, 
#just in case a user has all capitals on. 

        player = input('rock, sissors, paper? ').lower()

    
#after our input we get our conditionals. This is to evaluate the options
# what did the ogre choose, what did the player choose, who wins.

        if player == ogre:
            print('ogre chose', ogre, )
            print("tie")
            print('*'*40)
            tie += 1
            time.sleep(2)

        elif player == 'rock':
            if ogre == 'paper':
                print('ogre chose', ogre, )
                print('\nthe two lovely ladies loose', ogre, 'covers', player)
                c += 1
                print('*'*40)
                time.sleep(2)
            else: 
                print('ogre chose', ogre, )
                print('the two lovely ladies win.', player, 'smashes', ogre)
                p += 1
                print('*'*40)
                time.sleep(2)

        elif player == 'paper':
            if ogre == 'sissors':
                print('ogre chose', ogre,)
                print('\nthe two lovely ladies loose', ogre, 'cuts', player)
                c  += 1
                print('*'*40)
                time.sleep(2)
            else:
                print('ogre chose', ogre, )
                print('the two lovely ladies win', player, 'covers', ogre)
                p += 1
                print('*'*40)
                time.sleep(2)

        elif player == 'sissors':
            if ogre == 'rock':
                print('ogre chose', ogre,)
                print('\nthe two lovely ladies loose', ogre, 'smashes', player)
                c += 1
                print('*'*40)
                time.sleep(2)
            else:
                print('ogre chose', ogre, )
                print('the two lovely ladies win', player, 'cut', ogre)
                p += 1
                print('*'*40)
                time.sleep(2)

# If you typed in q the ogre will break the loop and end the game
        elif player == 'q':
          print("Thanks for playing")
          break
        
# if the user accidentially made a typo we tell the user then go back to the 
# input after 2 seconds    
        else:
            print('That is not a valid choice. Check your spelling')
        time.sleep(2)
    
        ogre = t[randint(0,2)]
    

# Once we broken out of the loop we display the final score 
    print()
    
    if p > c or p == c:
        print("The two lovely ladies win and get to live a happy life ever after")
    else:
        print("The Ogre won and ate the two lovely ladies")
