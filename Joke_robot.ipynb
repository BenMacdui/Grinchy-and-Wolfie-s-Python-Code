# %%
#@title The Joke Generator
import random
import time
from IPython.display import clear_output


dict = {
    "Why did the teddy bear say no to dessert?" : "Because he was stuffed",
    "Why did the chicken cross the sandpit?" : "... to get to the other slide",
    "What did the nose say to the finger?": "Stop picking on me",
    "Where does a snowman keep his money?" : "In a snow bank!",
    "What kind of motorcycle does Santa like to ride?" : "A Holly Davidson!",
    "How does a snowman lose weight?" : "He waits for the weather to get warmer",
    "Why was the sand wet?" : "Because the sea weed",
    "why did the tomato blush?" : "Because it saw the salad dressing",
    "What do you call a reindeer who wears earmuffs?" :"Anything you like, he can't hear you",
    "What do we do when lemons get sick?" : "Give lemon aid"
    
}

# we need to extract a list of the keys in our joke dictionary, so that the computer
# can choose a joke randomly
jokes_list = list(dict.keys())
random.shuffle(jokes_list)


# we setting the limit of jokes that the programme will go through. If there are hundreds,
#then you will want a limit
index = 0
limit = int(input("Give me the number of jokes you want the computer to tell (between 1 - 10)"))

# now let's go through our list one by one and count 
for index, joke in enumerate(jokes_list):
    if index == limit:
        break
    else:
        
        print("")
        print(f"{joke}")
        userinput_answer = input("Ask the computer to get the joke: ")
        print()
        time.sleep(2)
        print(dict[joke])
        print()
        print("boom boom \U0001F923")
        time.sleep(5)
        clear_output(wait=True)
    
print('Aww, this is the end. \U0001F622')
