# %% [markdown]
# <a href="https://colab.research.google.com/github/BenMacdui/Grinchy-and-Wolfie-s-Python-Code/blob/main/fractions_non_mixed_numbers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""We need to understand how fractions work in order to write a prgram 
that does the calculations for us.

Fractions are really ratios and 2/3 could be written also as 2:3 (2 parts out of 3)
The numerator is the number above the line, in 2/3 the numerator is 2
and the denominator is the bottom number, in 2/3 it is 3. 

Adding: We can only add fractions with the same denominator. If these are different
we need to find the least common denominator first. For example 2/3 + 2/4 we multiply 3*4 to 
find the least common denominator which is 12. 

We had to multiply the denominator of 2/3 by 4 to get 12, so we multiply the 
numerator of 2/3 by 4 also which equals 8. This gives us 8/12. And we do the same
with the other fraction
We multiply the denominator of the fraction 2/4 by 3 in order to get 12,
and the nominator of 2/4 by 3 which gives us 6 so we get 6/12. 

Now we can add both fractions together as the both have the same denominator,
namely 12: So we write 8/12 + 6/12 = 14/12. Simplifying the fraction we write:
14/12 = 7/6 = 1 1/6

Substracting: This is just the same as above only that we substract the nominators after we have found
the least common denominator

Multiplication: Here we multiply the nominators of the numbers and the denominators of the numbers.
In algebra this is written as a/b * c/d = ac/bd or with numbers 1/3 * 2/5 = 1*2/3*5 = 2/15

Division: In division we multiply the fraction by it's reciprocital 
(we turn the second fraction upside down)
Since we love algebra so much we write this as a/b / c/d = a/b * d/c 
This reads a over b divided by c over d equals a over b times d over c
Written in numbers 2/3 / 1/2 = 2/3 * 2/1 = 2*2/3*1 = 4/3 = 1 1/3

Mixed numbers: When we have mixed numbers we turn them first into improper fractions:
So for example 5 2/10 is turned into the improper fraction 52/10. 

This is done as follows the whole number 5 is written as a fraction 5/1 
to which we add 2/10. We now have to find the least common denominator as we have
seen above we cannot add fractions that do not have a common denominator
In order to find the least common denominator we just multiply by the denominator of the 
fraction part which is 10 (fraction part is 2/10, remember). We get:
1 * 10 and 5 * 10 = 50/10 
Now we can add 2/10 = 52/10. 

In the program snippet of Mixed numbers I just multiply the denominator of the fraction
with the whole number and add the numerator of the fraction to that.

Although my program can do exponentials and square roots of fractions I don't think
that will come up in S1 and S2 but if and when it does we will add this part

So now that we know how fractions work we can write a program to do the calculation for us
Why, says Wolfie, should we work harder than we need to when we can write a program
that does the boring work for us. The computer, says Wolfie, doesn't mind boring work. 
The computer loves boring work

Let us write a pseudo code first. That is a code that doesn't do anything but acts more
like a planning tool and we can see what we need to do"""



"""*****************************************************************
Pseudo code of fraction operations

IMPORT the fraction module from python as it does most of the work for us
Get user INPUT of fraction one either in form a/b or a,b
Get user INPUT of fraction 2
Get the operand in the form of +, -, /, *
Use IF CONDITIONAL statements to determine what operation is to be performed
Use IF CONDITIONAL statement to determine whether a fraction is improper
and if so give the result as a mixed number
print the result

end of pseudo code

***********************************************************************"""

"""there is a flaw in the mixed number printing as python sometimes prints 0/1 as rest (which doesn't exist)
what we have to do in this case is to take the result as just the whole number.
Example was 144/72 which python printed out 2 0/1. Since zero over 1 does not exist this means 
the result is 2, which it clearly is.  


***********************************************************************"""

# the code


from fractions import  Fraction as frac

'''determining whether a fraction is an improper fraction
and either printing a mixed number result or
a prettyfied fraction'''

# get user input for fractions
a = frac(input('Enter the first fraction in the form of a/b: '))
b = frac(input('Enter the second fraction in the form of a/b: '))

# get ooperand 
opp = input('Please enter the operand in the form of +, -, *, /  ')

#conditional statements for operand
if opp == '+':
    result = a + b
elif opp == "-":
    result = a - b
elif opp == '/':
    result = a / b
elif opp == '*':
    result = a * b
#elif opp == '**':
#    output = result ** result1


print()
print()

# check whether the result is an improper or a proper fraction
# and print out either a mixed number or a prettyfied fraction

if result.numerator / result.denominator >= 1:
    x = result.numerator // result.denominator
    y = result.numerator % result.denominator
    print()
    print(result.numerator, result.denominator,sep='\n--\n')
    print()
    print("mixed number result {} {}/{}".format(x, y, result.denominator))
else:
    #print('fraction') # insert code here for printing a prettified fraction
    print(result.numerator, result.denominator,sep='\n--\n')
